# %%
import json
import os
import math
import librosa

DATASET_PATH = "data/training_data"
JSON_PATH = "data_5.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=10):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: brunomars
# data/training_data/brunomars/bruno_57.wav, segment:1
# data/training_data/brunomars/bruno_57.wav, segment:2
# data/training_data/brunomars/bruno_57.wav, segment:3
# data/training_data/brunomars/bruno_57.wav, segment:4
# data/training_data/brunomars/bruno_57.wav, segment:5
# data/training_data/brunomars/bruno_57.wav, segment:6
# data/training_data/brunomars/bruno_57.wav, segment:7
# data/training_data/brunomars/bruno_57.wav, segment:8
# data/training_data/brunomars/bruno_57.wav, segment:9
# data/training_data/brunomars/bruno_57.wav, segment:10
# data/training_data/brunomars/bruno_43.wav, segment:1
# data/training_data/brunomars/bruno_43.wav, segment:2
# data/training_data/brunomars/bruno_43.wav, segment:3
# data/training_data/brunomars/bruno_43.wav, segment:4
# data/training_data/brunomars/bruno_43.wav, segment:5
# data/training_data/brunomars/bruno_43.wav, segment:6
# data/training_data/brunomars/bruno_43.wav, segment:7
# data/training_data/brunomars/bruno_43.wav, segment:8
# data/training_data/brunomars/bruno_43.wav, segment:9
# data/training_data/brunomars/bruno_94.wav, segment:1
# data/training_data/brunomars/bruno_94.wav, segment:2
# data/training_data/brunomars/bruno_94.wav, segment:3
# data/training_data/brunomars/bruno_94.wav, segment:4
# data/training_data/brunomars/bruno_94.wav, segment:5
# data/training_data/brunomars/bruno_94.wav, segment:6
# data/training_data/brunomars/bruno_94.wav, segment:7
# data/training_data/brunomars/bruno_94.wav, segment:8
# data/training_data/brunomars/bruno_94.wav, segment:9
# data/training_data/brunomars/bruno_80.wav, segment:1
# data/training_data/brunomars/bruno_80.wav, segment:2
# data/training_data/brunomars/bruno_80.wav, segment:3
# data/training_data/brunomars/bruno_80.wav, segment:4
# data/training_data/brunomars/bruno_80.wav, segment:5
# data/training_data/brunomars/bruno_80.wav, segment:6
# data/training_data/brunomars/bruno_80.wav, segment:7
# data/training_data/brunomars/bruno_80.wav, segment:8
# data/training_data/brunomars/bruno_80.wav, segment:9
# data/training_data/brunomars/bruno_81.wav, segment:1
# data/training_data/brunomars/bruno_81.wav, segment:2
# data/training_data/brunomars/bruno_81.wav, segment:3
# data/training_data/brunomars/bruno_81.wav, segment:4
# data/training_data/brunomars/bruno_81.wav, segment:5
# data/training_data/brunomars/bruno_81.wav, segment:6
# data/training_data/brunomars/bruno_81.wav, segment:7
# data/training_data/brunomars/bruno_81.wav, segment:8
# data/training_data/brunomars/bruno_81.wav, segment:9
# data/training_data/brunomars/bruno_81.wav, segment:10
# data/training_data/brunomars/bruno_95.wav, segment:1
# data/training_data/brunomars/bruno_95.wav, segment:2
# data/training_data/brunomars/bruno_95.wav, segment:3
# data/training_data/brunomars/bruno_95.wav, segment:4
# data/training_data/brunomars/bruno_95.wav, segment:5
# data/training_data/brunomars/bruno_95.wav, segment:6
# data/training_data/brunomars/bruno_95.wav, segment:7
# data/training_data/brunomars/bruno_95.wav, segment:8
# data/training_data/brunomars/bruno_95.wav, segment:9
# data/training_data/brunomars/bruno_42.wav, segment:1
# data/training_data/brunomars/bruno_42.wav, segment:2
# data/training_data/brunomars/bruno_42.wav, segment:3
# data/training_data/brunomars/bruno_42.wav, segment:4
# data/training_data/brunomars/bruno_42.wav, segment:5
# data/training_data/brunomars/bruno_42.wav, segment:6
# data/training_data/brunomars/bruno_42.wav, segment:7
# data/training_data/brunomars/bruno_42.wav, segment:8
# data/training_data/brunomars/bruno_42.wav, segment:9
# data/training_data/brunomars/bruno_56.wav, segment:1
# data/training_data/brunomars/bruno_56.wav, segment:2
# data/training_data/brunomars/bruno_56.wav, segment:3
# data/training_data/brunomars/bruno_56.wav, segment:4
# data/training_data/brunomars/bruno_56.wav, segment:5
# data/training_data/brunomars/bruno_56.wav, segment:6
# data/training_data/brunomars/bruno_56.wav, segment:7
# data/training_data/brunomars/bruno_56.wav, segment:8
# data/training_data/brunomars/bruno_56.wav, segment:9
# data/training_data/brunomars/bruno_68.wav, segment:1
# data/training_data/brunomars/bruno_68.wav, segment:2
# data/training_data/brunomars/bruno_68.wav, segment:3
# data/training_data/brunomars/bruno_68.wav, segment:4
# data/training_data/brunomars/bruno_68.wav, segment:5
# data/training_data/brunomars/bruno_68.wav, segment:6
# data/training_data/brunomars/bruno_68.wav, segment:7
# data/training_data/brunomars/bruno_68.wav, segment:8
# data/training_data/brunomars/bruno_68.wav, segment:9
# data/training_data/brunomars/bruno_40.wav, segment:1
# data/training_data/brunomars/bruno_40.wav, segment:2
# data/training_data/brunomars/bruno_40.wav, segment:3
# data/training_data/brunomars/bruno_40.wav, segment:4
# data/training_data/brunomars/bruno_40.wav, segment:5
# data/training_data/brunomars/bruno_40.wav, segment:6
# data/training_data/brunomars/bruno_40.wav, segment:7
# data/training_data/brunomars/bruno_40.wav, segment:8
# data/training_data/brunomars/bruno_40.wav, segment:9
# data/training_data/brunomars/bruno_54.wav, segment:1
# data/training_data/brunomars/bruno_54.wav, segment:2
# data/training_data/brunomars/bruno_54.wav, segment:3
# data/training_data/brunomars/bruno_54.wav, segment:4
# data/training_data/brunomars/bruno_54.wav, segment:5
# data/training_data/brunomars/bruno_54.wav, segment:6
# data/training_data/brunomars/bruno_54.wav, segment:7
# data/training_data/brunomars/bruno_54.wav, segment:8
# data/training_data/brunomars/bruno_54.wav, segment:9
# data/training_data/brunomars/bruno_83.wav, segment:1
# data/training_data/brunomars/bruno_83.wav, segment:2
# data/training_data/brunomars/bruno_83.wav, segment:3
# data/training_data/brunomars/bruno_83.wav, segment:4
# data/training_data/brunomars/bruno_83.wav, segment:5
# data/training_data/brunomars/bruno_83.wav, segment:6
# data/training_data/brunomars/bruno_83.wav, segment:7
# data/training_data/brunomars/bruno_83.wav, segment:8
# data/training_data/brunomars/bruno_83.wav, segment:9
# data/training_data/brunomars/bruno_97.wav, segment:1
# data/training_data/brunomars/bruno_97.wav, segment:2
# data/training_data/brunomars/bruno_97.wav, segment:3
# data/training_data/brunomars/bruno_97.wav, segment:4
# data/training_data/brunomars/bruno_97.wav, segment:5
# data/training_data/brunomars/bruno_97.wav, segment:6
# data/training_data/brunomars/bruno_97.wav, segment:7
# data/training_data/brunomars/bruno_97.wav, segment:8
# data/training_data/brunomars/bruno_97.wav, segment:9
# data/training_data/brunomars/bruno_8.wav, segment:1
# data/training_data/brunomars/bruno_8.wav, segment:2
# data/training_data/brunomars/bruno_8.wav, segment:3
# data/training_data/brunomars/bruno_8.wav, segment:4
# data/training_data/brunomars/bruno_8.wav, segment:5
# data/training_data/brunomars/bruno_8.wav, segment:6
# data/training_data/brunomars/bruno_8.wav, segment:7
# data/training_data/brunomars/bruno_8.wav, segment:8
# data/training_data/brunomars/bruno_8.wav, segment:9
# data/training_data/brunomars/bruno_9.wav, segment:1
# data/training_data/brunomars/bruno_9.wav, segment:2
# data/training_data/brunomars/bruno_9.wav, segment:3
# data/training_data/brunomars/bruno_9.wav, segment:4
# data/training_data/brunomars/bruno_9.wav, segment:5
# data/training_data/brunomars/bruno_9.wav, segment:6
# data/training_data/brunomars/bruno_9.wav, segment:7
# data/training_data/brunomars/bruno_9.wav, segment:8
# data/training_data/brunomars/bruno_9.wav, segment:9
# data/training_data/brunomars/bruno_9.wav, segment:10
# data/training_data/brunomars/bruno_96.wav, segment:1
# data/training_data/brunomars/bruno_96.wav, segment:2
# data/training_data/brunomars/bruno_96.wav, segment:3
# data/training_data/brunomars/bruno_96.wav, segment:4
# data/training_data/brunomars/bruno_96.wav, segment:5
# data/training_data/brunomars/bruno_96.wav, segment:6
# data/training_data/brunomars/bruno_96.wav, segment:7
# data/training_data/brunomars/bruno_96.wav, segment:8
# data/training_data/brunomars/bruno_96.wav, segment:9
# data/training_data/brunomars/bruno_82.wav, segment:1
# data/training_data/brunomars/bruno_82.wav, segment:2
# data/training_data/brunomars/bruno_82.wav, segment:3
# data/training_data/brunomars/bruno_82.wav, segment:4
# data/training_data/brunomars/bruno_82.wav, segment:5
# data/training_data/brunomars/bruno_82.wav, segment:6
# data/training_data/brunomars/bruno_82.wav, segment:7
# data/training_data/brunomars/bruno_82.wav, segment:8
# data/training_data/brunomars/bruno_82.wav, segment:9
# data/training_data/brunomars/bruno_55.wav, segment:1
# data/training_data/brunomars/bruno_55.wav, segment:2
# data/training_data/brunomars/bruno_55.wav, segment:3
# data/training_data/brunomars/bruno_55.wav, segment:4
# data/training_data/brunomars/bruno_55.wav, segment:5
# data/training_data/brunomars/bruno_55.wav, segment:6
# data/training_data/brunomars/bruno_55.wav, segment:7
# data/training_data/brunomars/bruno_55.wav, segment:8
# data/training_data/brunomars/bruno_55.wav, segment:9
# data/training_data/brunomars/bruno_41.wav, segment:1
# data/training_data/brunomars/bruno_41.wav, segment:2
# data/training_data/brunomars/bruno_41.wav, segment:3
# data/training_data/brunomars/bruno_41.wav, segment:4
# data/training_data/brunomars/bruno_41.wav, segment:5
# data/training_data/brunomars/bruno_41.wav, segment:6
# data/training_data/brunomars/bruno_41.wav, segment:7
# data/training_data/brunomars/bruno_41.wav, segment:8
# data/training_data/brunomars/bruno_41.wav, segment:9
# data/training_data/brunomars/bruno_69.wav, segment:1
# data/training_data/brunomars/bruno_69.wav, segment:2
# data/training_data/brunomars/bruno_69.wav, segment:3
# data/training_data/brunomars/bruno_69.wav, segment:4
# data/training_data/brunomars/bruno_69.wav, segment:5
# data/training_data/brunomars/bruno_69.wav, segment:6
# data/training_data/brunomars/bruno_69.wav, segment:7
# data/training_data/brunomars/bruno_69.wav, segment:8
# data/training_data/brunomars/bruno_69.wav, segment:9
# data/training_data/brunomars/bruno_69.wav, segment:10
# data/training_data/brunomars/bruno_45.wav, segment:1
# data/training_data/brunomars/bruno_45.wav, segment:2
# data/training_data/brunomars/bruno_45.wav, segment:3
# data/training_data/brunomars/bruno_45.wav, segment:4
# data/training_data/brunomars/bruno_45.wav, segment:5
# data/training_data/brunomars/bruno_45.wav, segment:6
# data/training_data/brunomars/bruno_45.wav, segment:7
# data/training_data/brunomars/bruno_45.wav, segment:8
# data/training_data/brunomars/bruno_45.wav, segment:9
# data/training_data/brunomars/bruno_51.wav, segment:1
# data/training_data/brunomars/bruno_51.wav, segment:2
# data/training_data/brunomars/bruno_51.wav, segment:3
# data/training_data/brunomars/bruno_51.wav, segment:4
# data/training_data/brunomars/bruno_51.wav, segment:5
# data/training_data/brunomars/bruno_51.wav, segment:6
# data/training_data/brunomars/bruno_51.wav, segment:7
# data/training_data/brunomars/bruno_51.wav, segment:8
# data/training_data/brunomars/bruno_51.wav, segment:9
# data/training_data/brunomars/bruno_51.wav, segment:10
# data/training_data/brunomars/bruno_79.wav, segment:1
# data/training_data/brunomars/bruno_79.wav, segment:2
# data/training_data/brunomars/bruno_79.wav, segment:3
# data/training_data/brunomars/bruno_79.wav, segment:4
# data/training_data/brunomars/bruno_79.wav, segment:5
# data/training_data/brunomars/bruno_79.wav, segment:6
# data/training_data/brunomars/bruno_79.wav, segment:7
# data/training_data/brunomars/bruno_79.wav, segment:8
# data/training_data/brunomars/bruno_79.wav, segment:9
# data/training_data/brunomars/bruno_86.wav, segment:1
# data/training_data/brunomars/bruno_86.wav, segment:2
# data/training_data/brunomars/bruno_86.wav, segment:3
# data/training_data/brunomars/bruno_86.wav, segment:4
# data/training_data/brunomars/bruno_86.wav, segment:5
# data/training_data/brunomars/bruno_86.wav, segment:6
# data/training_data/brunomars/bruno_86.wav, segment:7
# data/training_data/brunomars/bruno_86.wav, segment:8
# data/training_data/brunomars/bruno_86.wav, segment:9
# data/training_data/brunomars/bruno_92.wav, segment:1
# data/training_data/brunomars/bruno_92.wav, segment:2
# data/training_data/brunomars/bruno_92.wav, segment:3
# data/training_data/brunomars/bruno_92.wav, segment:4
# data/training_data/brunomars/bruno_92.wav, segment:5
# data/training_data/brunomars/bruno_92.wav, segment:6
# data/training_data/brunomars/bruno_92.wav, segment:7
# data/training_data/brunomars/bruno_92.wav, segment:8
# data/training_data/brunomars/bruno_92.wav, segment:9
# data/training_data/brunomars/bruno_93.wav, segment:1
# data/training_data/brunomars/bruno_93.wav, segment:2
# data/training_data/brunomars/bruno_93.wav, segment:3
# data/training_data/brunomars/bruno_93.wav, segment:4
# data/training_data/brunomars/bruno_93.wav, segment:5
# data/training_data/brunomars/bruno_93.wav, segment:6
# data/training_data/brunomars/bruno_93.wav, segment:7
# data/training_data/brunomars/bruno_93.wav, segment:8
# data/training_data/brunomars/bruno_93.wav, segment:9
# data/training_data/brunomars/bruno_93.wav, segment:10
# data/training_data/brunomars/bruno_87.wav, segment:1
# data/training_data/brunomars/bruno_87.wav, segment:2
# data/training_data/brunomars/bruno_87.wav, segment:3
# data/training_data/brunomars/bruno_87.wav, segment:4
# data/training_data/brunomars/bruno_87.wav, segment:5
# data/training_data/brunomars/bruno_87.wav, segment:6
# data/training_data/brunomars/bruno_87.wav, segment:7
# data/training_data/brunomars/bruno_87.wav, segment:8
# data/training_data/brunomars/bruno_87.wav, segment:9
# data/training_data/brunomars/bruno_87.wav, segment:10
# data/training_data/brunomars/bruno_78.wav, segment:1
# data/training_data/brunomars/bruno_78.wav, segment:2
# data/training_data/brunomars/bruno_78.wav, segment:3
# data/training_data/brunomars/bruno_78.wav, segment:4
# data/training_data/brunomars/bruno_78.wav, segment:5
# data/training_data/brunomars/bruno_78.wav, segment:6
# data/training_data/brunomars/bruno_78.wav, segment:7
# data/training_data/brunomars/bruno_78.wav, segment:8
# data/training_data/brunomars/bruno_78.wav, segment:9
# data/training_data/brunomars/bruno_50.wav, segment:1
# data/training_data/brunomars/bruno_50.wav, segment:2
# data/training_data/brunomars/bruno_50.wav, segment:3
# data/training_data/brunomars/bruno_50.wav, segment:4
# data/training_data/brunomars/bruno_50.wav, segment:5
# data/training_data/brunomars/bruno_50.wav, segment:6
# data/training_data/brunomars/bruno_50.wav, segment:7
# data/training_data/brunomars/bruno_50.wav, segment:8
# data/training_data/brunomars/bruno_50.wav, segment:9
# data/training_data/brunomars/bruno_44.wav, segment:1
# data/training_data/brunomars/bruno_44.wav, segment:2
# data/training_data/brunomars/bruno_44.wav, segment:3
# data/training_data/brunomars/bruno_44.wav, segment:4
# data/training_data/brunomars/bruno_44.wav, segment:5
# data/training_data/brunomars/bruno_44.wav, segment:6
# data/training_data/brunomars/bruno_44.wav, segment:7
# data/training_data/brunomars/bruno_44.wav, segment:8
# data/training_data/brunomars/bruno_44.wav, segment:9
# data/training_data/brunomars/bruno_44.wav, segment:10
# data/training_data/brunomars/bruno_100.wav, segment:1
# data/training_data/brunomars/bruno_100.wav, segment:2
# data/training_data/brunomars/bruno_100.wav, segment:3
# data/training_data/brunomars/bruno_100.wav, segment:4
# data/training_data/brunomars/bruno_100.wav, segment:5
# data/training_data/brunomars/bruno_100.wav, segment:6
# data/training_data/brunomars/bruno_100.wav, segment:7
# data/training_data/brunomars/bruno_100.wav, segment:8
# data/training_data/brunomars/bruno_100.wav, segment:9
# data/training_data/brunomars/bruno_100.wav, segment:10
# data/training_data/brunomars/bruno_52.wav, segment:1
# data/training_data/brunomars/bruno_52.wav, segment:2
# data/training_data/brunomars/bruno_52.wav, segment:3
# data/training_data/brunomars/bruno_52.wav, segment:4
# data/training_data/brunomars/bruno_52.wav, segment:5
# data/training_data/brunomars/bruno_52.wav, segment:6
# data/training_data/brunomars/bruno_52.wav, segment:7
# data/training_data/brunomars/bruno_52.wav, segment:8
# data/training_data/brunomars/bruno_52.wav, segment:9
# data/training_data/brunomars/bruno_46.wav, segment:1
# data/training_data/brunomars/bruno_46.wav, segment:2
# data/training_data/brunomars/bruno_46.wav, segment:3
# data/training_data/brunomars/bruno_46.wav, segment:4
# data/training_data/brunomars/bruno_46.wav, segment:5
# data/training_data/brunomars/bruno_46.wav, segment:6
# data/training_data/brunomars/bruno_46.wav, segment:7
# data/training_data/brunomars/bruno_46.wav, segment:8
# data/training_data/brunomars/bruno_46.wav, segment:9
# data/training_data/brunomars/bruno_91.wav, segment:1
# data/training_data/brunomars/bruno_91.wav, segment:2
# data/training_data/brunomars/bruno_91.wav, segment:3
# data/training_data/brunomars/bruno_91.wav, segment:4
# data/training_data/brunomars/bruno_91.wav, segment:5
# data/training_data/brunomars/bruno_91.wav, segment:6
# data/training_data/brunomars/bruno_91.wav, segment:7
# data/training_data/brunomars/bruno_91.wav, segment:8
# data/training_data/brunomars/bruno_91.wav, segment:9
# data/training_data/brunomars/bruno_85.wav, segment:1
# data/training_data/brunomars/bruno_85.wav, segment:2
# data/training_data/brunomars/bruno_85.wav, segment:3
# data/training_data/brunomars/bruno_85.wav, segment:4
# data/training_data/brunomars/bruno_85.wav, segment:5
# data/training_data/brunomars/bruno_85.wav, segment:6
# data/training_data/brunomars/bruno_85.wav, segment:7
# data/training_data/brunomars/bruno_85.wav, segment:8
# data/training_data/brunomars/bruno_85.wav, segment:9
# data/training_data/brunomars/bruno_84.wav, segment:1
# data/training_data/brunomars/bruno_84.wav, segment:2
# data/training_data/brunomars/bruno_84.wav, segment:3
# data/training_data/brunomars/bruno_84.wav, segment:4
# data/training_data/brunomars/bruno_84.wav, segment:5
# data/training_data/brunomars/bruno_84.wav, segment:6
# data/training_data/brunomars/bruno_84.wav, segment:7
# data/training_data/brunomars/bruno_84.wav, segment:8
# data/training_data/brunomars/bruno_84.wav, segment:9
# data/training_data/brunomars/bruno_90.wav, segment:1
# data/training_data/brunomars/bruno_90.wav, segment:2
# data/training_data/brunomars/bruno_90.wav, segment:3
# data/training_data/brunomars/bruno_90.wav, segment:4
# data/training_data/brunomars/bruno_90.wav, segment:5
# data/training_data/brunomars/bruno_90.wav, segment:6
# data/training_data/brunomars/bruno_90.wav, segment:7
# data/training_data/brunomars/bruno_90.wav, segment:8
# data/training_data/brunomars/bruno_90.wav, segment:9
# data/training_data/brunomars/bruno_47.wav, segment:1
# data/training_data/brunomars/bruno_47.wav, segment:2
# data/training_data/brunomars/bruno_47.wav, segment:3
# data/training_data/brunomars/bruno_47.wav, segment:4
# data/training_data/brunomars/bruno_47.wav, segment:5
# data/training_data/brunomars/bruno_47.wav, segment:6
# data/training_data/brunomars/bruno_47.wav, segment:7
# data/training_data/brunomars/bruno_47.wav, segment:8
# data/training_data/brunomars/bruno_47.wav, segment:9
# data/training_data/brunomars/bruno_53.wav, segment:1
# data/training_data/brunomars/bruno_53.wav, segment:2
# data/training_data/brunomars/bruno_53.wav, segment:3
# data/training_data/brunomars/bruno_53.wav, segment:4
# data/training_data/brunomars/bruno_53.wav, segment:5
# data/training_data/brunomars/bruno_53.wav, segment:6
# data/training_data/brunomars/bruno_53.wav, segment:7
# data/training_data/brunomars/bruno_53.wav, segment:8
# data/training_data/brunomars/bruno_53.wav, segment:9
# data/training_data/brunomars/bruno_34.wav, segment:1
# data/training_data/brunomars/bruno_34.wav, segment:2
# data/training_data/brunomars/bruno_34.wav, segment:3
# data/training_data/brunomars/bruno_34.wav, segment:4
# data/training_data/brunomars/bruno_34.wav, segment:5
# data/training_data/brunomars/bruno_34.wav, segment:6
# data/training_data/brunomars/bruno_34.wav, segment:7
# data/training_data/brunomars/bruno_34.wav, segment:8
# data/training_data/brunomars/bruno_34.wav, segment:9
# data/training_data/brunomars/bruno_34.wav, segment:10
# data/training_data/brunomars/bruno_20.wav, segment:1
# data/training_data/brunomars/bruno_20.wav, segment:2
# data/training_data/brunomars/bruno_20.wav, segment:3
# data/training_data/brunomars/bruno_20.wav, segment:4
# data/training_data/brunomars/bruno_20.wav, segment:5
# data/training_data/brunomars/bruno_20.wav, segment:6
# data/training_data/brunomars/bruno_20.wav, segment:7
# data/training_data/brunomars/bruno_20.wav, segment:8
# data/training_data/brunomars/bruno_20.wav, segment:9
# data/training_data/brunomars/bruno_21.wav, segment:1
# data/training_data/brunomars/bruno_21.wav, segment:2
# data/training_data/brunomars/bruno_21.wav, segment:3
# data/training_data/brunomars/bruno_21.wav, segment:4
# data/training_data/brunomars/bruno_21.wav, segment:5
# data/training_data/brunomars/bruno_21.wav, segment:6
# data/training_data/brunomars/bruno_21.wav, segment:7
# data/training_data/brunomars/bruno_21.wav, segment:8
# data/training_data/brunomars/bruno_21.wav, segment:9
# data/training_data/brunomars/bruno_35.wav, segment:1
# data/training_data/brunomars/bruno_35.wav, segment:2
# data/training_data/brunomars/bruno_35.wav, segment:3
# data/training_data/brunomars/bruno_35.wav, segment:4
# data/training_data/brunomars/bruno_35.wav, segment:5
# data/training_data/brunomars/bruno_35.wav, segment:6
# data/training_data/brunomars/bruno_35.wav, segment:7
# data/training_data/brunomars/bruno_35.wav, segment:8
# data/training_data/brunomars/bruno_35.wav, segment:9
# data/training_data/brunomars/bruno_23.wav, segment:1
# data/training_data/brunomars/bruno_23.wav, segment:2
# data/training_data/brunomars/bruno_23.wav, segment:3
# data/training_data/brunomars/bruno_23.wav, segment:4
# data/training_data/brunomars/bruno_23.wav, segment:5
# data/training_data/brunomars/bruno_23.wav, segment:6
# data/training_data/brunomars/bruno_23.wav, segment:7
# data/training_data/brunomars/bruno_23.wav, segment:8
# data/training_data/brunomars/bruno_23.wav, segment:9
# data/training_data/brunomars/bruno_23.wav, segment:10
# data/training_data/brunomars/bruno_37.wav, segment:1
# data/training_data/brunomars/bruno_37.wav, segment:2
# data/training_data/brunomars/bruno_37.wav, segment:3
# data/training_data/brunomars/bruno_37.wav, segment:4
# data/training_data/brunomars/bruno_37.wav, segment:5
# data/training_data/brunomars/bruno_37.wav, segment:6
# data/training_data/brunomars/bruno_37.wav, segment:7
# data/training_data/brunomars/bruno_37.wav, segment:8
# data/training_data/brunomars/bruno_37.wav, segment:9
# data/training_data/brunomars/bruno_36.wav, segment:1
# data/training_data/brunomars/bruno_36.wav, segment:2
# data/training_data/brunomars/bruno_36.wav, segment:3
# data/training_data/brunomars/bruno_36.wav, segment:4
# data/training_data/brunomars/bruno_36.wav, segment:5
# data/training_data/brunomars/bruno_36.wav, segment:6
# data/training_data/brunomars/bruno_36.wav, segment:7
# data/training_data/brunomars/bruno_36.wav, segment:8
# data/training_data/brunomars/bruno_36.wav, segment:9
# data/training_data/brunomars/bruno_22.wav, segment:1
# data/training_data/brunomars/bruno_22.wav, segment:2
# data/training_data/brunomars/bruno_22.wav, segment:3
# data/training_data/brunomars/bruno_22.wav, segment:4
# data/training_data/brunomars/bruno_22.wav, segment:5
# data/training_data/brunomars/bruno_22.wav, segment:6
# data/training_data/brunomars/bruno_22.wav, segment:7
# data/training_data/brunomars/bruno_22.wav, segment:8
# data/training_data/brunomars/bruno_22.wav, segment:9
# data/training_data/brunomars/bruno_26.wav, segment:1
# data/training_data/brunomars/bruno_26.wav, segment:2
# data/training_data/brunomars/bruno_26.wav, segment:3
# data/training_data/brunomars/bruno_26.wav, segment:4
# data/training_data/brunomars/bruno_26.wav, segment:5
# data/training_data/brunomars/bruno_26.wav, segment:6
# data/training_data/brunomars/bruno_26.wav, segment:7
# data/training_data/brunomars/bruno_26.wav, segment:8
# data/training_data/brunomars/bruno_26.wav, segment:9
# data/training_data/brunomars/bruno_32.wav, segment:1
# data/training_data/brunomars/bruno_32.wav, segment:2
# data/training_data/brunomars/bruno_32.wav, segment:3
# data/training_data/brunomars/bruno_32.wav, segment:4
# data/training_data/brunomars/bruno_32.wav, segment:5
# data/training_data/brunomars/bruno_32.wav, segment:6
# data/training_data/brunomars/bruno_32.wav, segment:7
# data/training_data/brunomars/bruno_32.wav, segment:8
# data/training_data/brunomars/bruno_32.wav, segment:9
# data/training_data/brunomars/bruno_33.wav, segment:1
# data/training_data/brunomars/bruno_33.wav, segment:2
# data/training_data/brunomars/bruno_33.wav, segment:3
# data/training_data/brunomars/bruno_33.wav, segment:4
# data/training_data/brunomars/bruno_33.wav, segment:5
# data/training_data/brunomars/bruno_33.wav, segment:6
# data/training_data/brunomars/bruno_33.wav, segment:7
# data/training_data/brunomars/bruno_33.wav, segment:8
# data/training_data/brunomars/bruno_33.wav, segment:9
# data/training_data/brunomars/bruno_27.wav, segment:1
# data/training_data/brunomars/bruno_27.wav, segment:2
# data/training_data/brunomars/bruno_27.wav, segment:3
# data/training_data/brunomars/bruno_27.wav, segment:4
# data/training_data/brunomars/bruno_27.wav, segment:5
# data/training_data/brunomars/bruno_27.wav, segment:6
# data/training_data/brunomars/bruno_27.wav, segment:7
# data/training_data/brunomars/bruno_27.wav, segment:8
# data/training_data/brunomars/bruno_27.wav, segment:9
# data/training_data/brunomars/bruno_27.wav, segment:10
# data/training_data/brunomars/bruno_31.wav, segment:1
# data/training_data/brunomars/bruno_31.wav, segment:2
# data/training_data/brunomars/bruno_31.wav, segment:3
# data/training_data/brunomars/bruno_31.wav, segment:4
# data/training_data/brunomars/bruno_31.wav, segment:5
# data/training_data/brunomars/bruno_31.wav, segment:6
# data/training_data/brunomars/bruno_31.wav, segment:7
# data/training_data/brunomars/bruno_31.wav, segment:8
# data/training_data/brunomars/bruno_31.wav, segment:9
# data/training_data/brunomars/bruno_25.wav, segment:1
# data/training_data/brunomars/bruno_25.wav, segment:2
# data/training_data/brunomars/bruno_25.wav, segment:3
# data/training_data/brunomars/bruno_25.wav, segment:4
# data/training_data/brunomars/bruno_25.wav, segment:5
# data/training_data/brunomars/bruno_25.wav, segment:6
# data/training_data/brunomars/bruno_25.wav, segment:7
# data/training_data/brunomars/bruno_25.wav, segment:8
# data/training_data/brunomars/bruno_25.wav, segment:9
# data/training_data/brunomars/bruno_19.wav, segment:1
# data/training_data/brunomars/bruno_19.wav, segment:2
# data/training_data/brunomars/bruno_19.wav, segment:3
# data/training_data/brunomars/bruno_19.wav, segment:4
# data/training_data/brunomars/bruno_19.wav, segment:5
# data/training_data/brunomars/bruno_19.wav, segment:6
# data/training_data/brunomars/bruno_19.wav, segment:7
# data/training_data/brunomars/bruno_19.wav, segment:8
# data/training_data/brunomars/bruno_19.wav, segment:9
# data/training_data/brunomars/bruno_19.wav, segment:10
# data/training_data/brunomars/bruno_18.wav, segment:1
# data/training_data/brunomars/bruno_18.wav, segment:2
# data/training_data/brunomars/bruno_18.wav, segment:3
# data/training_data/brunomars/bruno_18.wav, segment:4
# data/training_data/brunomars/bruno_18.wav, segment:5
# data/training_data/brunomars/bruno_18.wav, segment:6
# data/training_data/brunomars/bruno_18.wav, segment:7
# data/training_data/brunomars/bruno_18.wav, segment:8
# data/training_data/brunomars/bruno_18.wav, segment:9
# data/training_data/brunomars/bruno_24.wav, segment:1
# data/training_data/brunomars/bruno_24.wav, segment:2
# data/training_data/brunomars/bruno_24.wav, segment:3
# data/training_data/brunomars/bruno_24.wav, segment:4
# data/training_data/brunomars/bruno_24.wav, segment:5
# data/training_data/brunomars/bruno_24.wav, segment:6
# data/training_data/brunomars/bruno_24.wav, segment:7
# data/training_data/brunomars/bruno_24.wav, segment:8
# data/training_data/brunomars/bruno_24.wav, segment:9
# data/training_data/brunomars/bruno_30.wav, segment:1
# data/training_data/brunomars/bruno_30.wav, segment:2
# data/training_data/brunomars/bruno_30.wav, segment:3
# data/training_data/brunomars/bruno_30.wav, segment:4
# data/training_data/brunomars/bruno_30.wav, segment:5
# data/training_data/brunomars/bruno_30.wav, segment:6
# data/training_data/brunomars/bruno_30.wav, segment:7
# data/training_data/brunomars/bruno_30.wav, segment:8
# data/training_data/brunomars/bruno_30.wav, segment:9
# data/training_data/brunomars/bruno_29.wav, segment:1
# data/training_data/brunomars/bruno_29.wav, segment:2
# data/training_data/brunomars/bruno_29.wav, segment:3
# data/training_data/brunomars/bruno_29.wav, segment:4
# data/training_data/brunomars/bruno_29.wav, segment:5
# data/training_data/brunomars/bruno_29.wav, segment:6
# data/training_data/brunomars/bruno_29.wav, segment:7
# data/training_data/brunomars/bruno_29.wav, segment:8
# data/training_data/brunomars/bruno_29.wav, segment:9
# data/training_data/brunomars/bruno_15.wav, segment:1
# data/training_data/brunomars/bruno_15.wav, segment:2
# data/training_data/brunomars/bruno_15.wav, segment:3
# data/training_data/brunomars/bruno_15.wav, segment:4
# data/training_data/brunomars/bruno_15.wav, segment:5
# data/training_data/brunomars/bruno_15.wav, segment:6
# data/training_data/brunomars/bruno_15.wav, segment:7
# data/training_data/brunomars/bruno_15.wav, segment:8
# data/training_data/brunomars/bruno_15.wav, segment:9
# data/training_data/brunomars/bruno_15.wav, segment:10
# data/training_data/brunomars/bruno_14.wav, segment:1
# data/training_data/brunomars/bruno_14.wav, segment:2
# data/training_data/brunomars/bruno_14.wav, segment:3
# data/training_data/brunomars/bruno_14.wav, segment:4
# data/training_data/brunomars/bruno_14.wav, segment:5
# data/training_data/brunomars/bruno_14.wav, segment:6
# data/training_data/brunomars/bruno_14.wav, segment:7
# data/training_data/brunomars/bruno_14.wav, segment:8
# data/training_data/brunomars/bruno_14.wav, segment:9
# data/training_data/brunomars/bruno_28.wav, segment:1
# data/training_data/brunomars/bruno_28.wav, segment:2
# data/training_data/brunomars/bruno_28.wav, segment:3
# data/training_data/brunomars/bruno_28.wav, segment:4
# data/training_data/brunomars/bruno_28.wav, segment:5
# data/training_data/brunomars/bruno_28.wav, segment:6
# data/training_data/brunomars/bruno_28.wav, segment:7
# data/training_data/brunomars/bruno_28.wav, segment:8
# data/training_data/brunomars/bruno_28.wav, segment:9
# data/training_data/brunomars/bruno_16.wav, segment:1
# data/training_data/brunomars/bruno_16.wav, segment:2
# data/training_data/brunomars/bruno_16.wav, segment:3
# data/training_data/brunomars/bruno_16.wav, segment:4
# data/training_data/brunomars/bruno_16.wav, segment:5
# data/training_data/brunomars/bruno_16.wav, segment:6
# data/training_data/brunomars/bruno_16.wav, segment:7
# data/training_data/brunomars/bruno_16.wav, segment:8
# data/training_data/brunomars/bruno_16.wav, segment:9
# data/training_data/brunomars/bruno_17.wav, segment:1
# data/training_data/brunomars/bruno_17.wav, segment:2
# data/training_data/brunomars/bruno_17.wav, segment:3
# data/training_data/brunomars/bruno_17.wav, segment:4
# data/training_data/brunomars/bruno_17.wav, segment:5
# data/training_data/brunomars/bruno_17.wav, segment:6
# data/training_data/brunomars/bruno_17.wav, segment:7
# data/training_data/brunomars/bruno_17.wav, segment:8
# data/training_data/brunomars/bruno_17.wav, segment:9
# data/training_data/brunomars/bruno_13.wav, segment:1
# data/training_data/brunomars/bruno_13.wav, segment:2
# data/training_data/brunomars/bruno_13.wav, segment:3
# data/training_data/brunomars/bruno_13.wav, segment:4
# data/training_data/brunomars/bruno_13.wav, segment:5
# data/training_data/brunomars/bruno_13.wav, segment:6
# data/training_data/brunomars/bruno_13.wav, segment:7
# data/training_data/brunomars/bruno_13.wav, segment:8
# data/training_data/brunomars/bruno_13.wav, segment:9
# data/training_data/brunomars/bruno_12.wav, segment:1
# data/training_data/brunomars/bruno_12.wav, segment:2
# data/training_data/brunomars/bruno_12.wav, segment:3
# data/training_data/brunomars/bruno_12.wav, segment:4
# data/training_data/brunomars/bruno_12.wav, segment:5
# data/training_data/brunomars/bruno_12.wav, segment:6
# data/training_data/brunomars/bruno_12.wav, segment:7
# data/training_data/brunomars/bruno_12.wav, segment:8
# data/training_data/brunomars/bruno_12.wav, segment:9
# data/training_data/brunomars/bruno_10.wav, segment:1
# data/training_data/brunomars/bruno_10.wav, segment:2
# data/training_data/brunomars/bruno_10.wav, segment:3
# data/training_data/brunomars/bruno_10.wav, segment:4
# data/training_data/brunomars/bruno_10.wav, segment:5
# data/training_data/brunomars/bruno_10.wav, segment:6
# data/training_data/brunomars/bruno_10.wav, segment:7
# data/training_data/brunomars/bruno_10.wav, segment:8
# data/training_data/brunomars/bruno_10.wav, segment:9
# data/training_data/brunomars/bruno_38.wav, segment:1
# data/training_data/brunomars/bruno_38.wav, segment:2
# data/training_data/brunomars/bruno_38.wav, segment:3
# data/training_data/brunomars/bruno_38.wav, segment:4
# data/training_data/brunomars/bruno_38.wav, segment:5
# data/training_data/brunomars/bruno_38.wav, segment:6
# data/training_data/brunomars/bruno_38.wav, segment:7
# data/training_data/brunomars/bruno_38.wav, segment:8
# data/training_data/brunomars/bruno_38.wav, segment:9
# data/training_data/brunomars/bruno_38.wav, segment:10
# data/training_data/brunomars/bruno_39.wav, segment:1
# data/training_data/brunomars/bruno_39.wav, segment:2
# data/training_data/brunomars/bruno_39.wav, segment:3
# data/training_data/brunomars/bruno_39.wav, segment:4
# data/training_data/brunomars/bruno_39.wav, segment:5
# data/training_data/brunomars/bruno_39.wav, segment:6
# data/training_data/brunomars/bruno_39.wav, segment:7
# data/training_data/brunomars/bruno_39.wav, segment:8
# data/training_data/brunomars/bruno_39.wav, segment:9
# data/training_data/brunomars/bruno_11.wav, segment:1
# data/training_data/brunomars/bruno_11.wav, segment:2
# data/training_data/brunomars/bruno_11.wav, segment:3
# data/training_data/brunomars/bruno_11.wav, segment:4
# data/training_data/brunomars/bruno_11.wav, segment:5
# data/training_data/brunomars/bruno_11.wav, segment:6
# data/training_data/brunomars/bruno_11.wav, segment:7
# data/training_data/brunomars/bruno_11.wav, segment:8
# data/training_data/brunomars/bruno_11.wav, segment:9
# data/training_data/brunomars/bruno_11.wav, segment:10
# data/training_data/brunomars/bruno_76.wav, segment:1
# data/training_data/brunomars/bruno_76.wav, segment:2
# data/training_data/brunomars/bruno_76.wav, segment:3
# data/training_data/brunomars/bruno_76.wav, segment:4
# data/training_data/brunomars/bruno_76.wav, segment:5
# data/training_data/brunomars/bruno_76.wav, segment:6
# data/training_data/brunomars/bruno_76.wav, segment:7
# data/training_data/brunomars/bruno_76.wav, segment:8
# data/training_data/brunomars/bruno_76.wav, segment:9
# data/training_data/brunomars/bruno_62.wav, segment:1
# data/training_data/brunomars/bruno_62.wav, segment:2
# data/training_data/brunomars/bruno_62.wav, segment:3
# data/training_data/brunomars/bruno_62.wav, segment:4
# data/training_data/brunomars/bruno_62.wav, segment:5
# data/training_data/brunomars/bruno_62.wav, segment:6
# data/training_data/brunomars/bruno_62.wav, segment:7
# data/training_data/brunomars/bruno_62.wav, segment:8
# data/training_data/brunomars/bruno_62.wav, segment:9
# data/training_data/brunomars/bruno_89.wav, segment:1
# data/training_data/brunomars/bruno_89.wav, segment:2
# data/training_data/brunomars/bruno_89.wav, segment:3
# data/training_data/brunomars/bruno_89.wav, segment:4
# data/training_data/brunomars/bruno_89.wav, segment:5
# data/training_data/brunomars/bruno_89.wav, segment:6
# data/training_data/brunomars/bruno_89.wav, segment:7
# data/training_data/brunomars/bruno_89.wav, segment:8
# data/training_data/brunomars/bruno_89.wav, segment:9
# data/training_data/brunomars/bruno_2.wav, segment:1
# data/training_data/brunomars/bruno_2.wav, segment:2
# data/training_data/brunomars/bruno_2.wav, segment:3
# data/training_data/brunomars/bruno_2.wav, segment:4
# data/training_data/brunomars/bruno_2.wav, segment:5
# data/training_data/brunomars/bruno_2.wav, segment:6
# data/training_data/brunomars/bruno_2.wav, segment:7
# data/training_data/brunomars/bruno_2.wav, segment:8
# data/training_data/brunomars/bruno_2.wav, segment:9
# data/training_data/brunomars/bruno_3.wav, segment:1
# data/training_data/brunomars/bruno_3.wav, segment:2
# data/training_data/brunomars/bruno_3.wav, segment:3
# data/training_data/brunomars/bruno_3.wav, segment:4
# data/training_data/brunomars/bruno_3.wav, segment:5
# data/training_data/brunomars/bruno_3.wav, segment:6
# data/training_data/brunomars/bruno_3.wav, segment:7
# data/training_data/brunomars/bruno_3.wav, segment:8
# data/training_data/brunomars/bruno_3.wav, segment:9
# data/training_data/brunomars/bruno_3.wav, segment:10
# data/training_data/brunomars/bruno_88.wav, segment:1
# data/training_data/brunomars/bruno_88.wav, segment:2
# data/training_data/brunomars/bruno_88.wav, segment:3
# data/training_data/brunomars/bruno_88.wav, segment:4
# data/training_data/brunomars/bruno_88.wav, segment:5
# data/training_data/brunomars/bruno_88.wav, segment:6
# data/training_data/brunomars/bruno_88.wav, segment:7
# data/training_data/brunomars/bruno_88.wav, segment:8
# data/training_data/brunomars/bruno_88.wav, segment:9
# data/training_data/brunomars/bruno_63.wav, segment:1
# data/training_data/brunomars/bruno_63.wav, segment:2
# data/training_data/brunomars/bruno_63.wav, segment:3
# data/training_data/brunomars/bruno_63.wav, segment:4
# data/training_data/brunomars/bruno_63.wav, segment:5
# data/training_data/brunomars/bruno_63.wav, segment:6
# data/training_data/brunomars/bruno_63.wav, segment:7
# data/training_data/brunomars/bruno_63.wav, segment:8
# data/training_data/brunomars/bruno_63.wav, segment:9
# data/training_data/brunomars/bruno_63.wav, segment:10
# data/training_data/brunomars/bruno_77.wav, segment:1
# data/training_data/brunomars/bruno_77.wav, segment:2
# data/training_data/brunomars/bruno_77.wav, segment:3
# data/training_data/brunomars/bruno_77.wav, segment:4
# data/training_data/brunomars/bruno_77.wav, segment:5
# data/training_data/brunomars/bruno_77.wav, segment:6
# data/training_data/brunomars/bruno_77.wav, segment:7
# data/training_data/brunomars/bruno_77.wav, segment:8
# data/training_data/brunomars/bruno_77.wav, segment:9
# data/training_data/brunomars/bruno_49.wav, segment:1
# data/training_data/brunomars/bruno_49.wav, segment:2
# data/training_data/brunomars/bruno_49.wav, segment:3
# data/training_data/brunomars/bruno_49.wav, segment:4
# data/training_data/brunomars/bruno_49.wav, segment:5
# data/training_data/brunomars/bruno_49.wav, segment:6
# data/training_data/brunomars/bruno_49.wav, segment:7
# data/training_data/brunomars/bruno_49.wav, segment:8
# data/training_data/brunomars/bruno_49.wav, segment:9
# data/training_data/brunomars/bruno_61.wav, segment:1
# data/training_data/brunomars/bruno_61.wav, segment:2
# data/training_data/brunomars/bruno_61.wav, segment:3
# data/training_data/brunomars/bruno_61.wav, segment:4
# data/training_data/brunomars/bruno_61.wav, segment:5
# data/training_data/brunomars/bruno_61.wav, segment:6
# data/training_data/brunomars/bruno_61.wav, segment:7
# data/training_data/brunomars/bruno_61.wav, segment:8
# data/training_data/brunomars/bruno_61.wav, segment:9
# data/training_data/brunomars/bruno_75.wav, segment:1
# data/training_data/brunomars/bruno_75.wav, segment:2
# data/training_data/brunomars/bruno_75.wav, segment:3
# data/training_data/brunomars/bruno_75.wav, segment:4
# data/training_data/brunomars/bruno_75.wav, segment:5
# data/training_data/brunomars/bruno_75.wav, segment:6
# data/training_data/brunomars/bruno_75.wav, segment:7
# data/training_data/brunomars/bruno_75.wav, segment:8
# data/training_data/brunomars/bruno_75.wav, segment:9
# data/training_data/brunomars/bruno_75.wav, segment:10
# data/training_data/brunomars/bruno_1.wav, segment:1
# data/training_data/brunomars/bruno_1.wav, segment:2
# data/training_data/brunomars/bruno_1.wav, segment:3
# data/training_data/brunomars/bruno_1.wav, segment:4
# data/training_data/brunomars/bruno_1.wav, segment:5
# data/training_data/brunomars/bruno_1.wav, segment:6
# data/training_data/brunomars/bruno_1.wav, segment:7
# data/training_data/brunomars/bruno_1.wav, segment:8
# data/training_data/brunomars/bruno_1.wav, segment:9
# data/training_data/brunomars/bruno_1.wav, segment:10
# data/training_data/brunomars/bruno_74.wav, segment:1
# data/training_data/brunomars/bruno_74.wav, segment:2
# data/training_data/brunomars/bruno_74.wav, segment:3
# data/training_data/brunomars/bruno_74.wav, segment:4
# data/training_data/brunomars/bruno_74.wav, segment:5
# data/training_data/brunomars/bruno_74.wav, segment:6
# data/training_data/brunomars/bruno_74.wav, segment:7
# data/training_data/brunomars/bruno_74.wav, segment:8
# data/training_data/brunomars/bruno_74.wav, segment:9
# data/training_data/brunomars/bruno_60.wav, segment:1
# data/training_data/brunomars/bruno_60.wav, segment:2
# data/training_data/brunomars/bruno_60.wav, segment:3
# data/training_data/brunomars/bruno_60.wav, segment:4
# data/training_data/brunomars/bruno_60.wav, segment:5
# data/training_data/brunomars/bruno_60.wav, segment:6
# data/training_data/brunomars/bruno_60.wav, segment:7
# data/training_data/brunomars/bruno_60.wav, segment:8
# data/training_data/brunomars/bruno_60.wav, segment:9
# data/training_data/brunomars/bruno_48.wav, segment:1
# data/training_data/brunomars/bruno_48.wav, segment:2
# data/training_data/brunomars/bruno_48.wav, segment:3
# data/training_data/brunomars/bruno_48.wav, segment:4
# data/training_data/brunomars/bruno_48.wav, segment:5
# data/training_data/brunomars/bruno_48.wav, segment:6
# data/training_data/brunomars/bruno_48.wav, segment:7
# data/training_data/brunomars/bruno_48.wav, segment:8
# data/training_data/brunomars/bruno_48.wav, segment:9
# data/training_data/brunomars/bruno_64.wav, segment:1
# data/training_data/brunomars/bruno_64.wav, segment:2
# data/training_data/brunomars/bruno_64.wav, segment:3
# data/training_data/brunomars/bruno_64.wav, segment:4
# data/training_data/brunomars/bruno_64.wav, segment:5
# data/training_data/brunomars/bruno_64.wav, segment:6
# data/training_data/brunomars/bruno_64.wav, segment:7
# data/training_data/brunomars/bruno_64.wav, segment:8
# data/training_data/brunomars/bruno_64.wav, segment:9
# data/training_data/brunomars/bruno_70.wav, segment:1
# data/training_data/brunomars/bruno_70.wav, segment:2
# data/training_data/brunomars/bruno_70.wav, segment:3
# data/training_data/brunomars/bruno_70.wav, segment:4
# data/training_data/brunomars/bruno_70.wav, segment:5
# data/training_data/brunomars/bruno_70.wav, segment:6
# data/training_data/brunomars/bruno_70.wav, segment:7
# data/training_data/brunomars/bruno_70.wav, segment:8
# data/training_data/brunomars/bruno_70.wav, segment:9
# data/training_data/brunomars/bruno_58.wav, segment:1
# data/training_data/brunomars/bruno_58.wav, segment:2
# data/training_data/brunomars/bruno_58.wav, segment:3
# data/training_data/brunomars/bruno_58.wav, segment:4
# data/training_data/brunomars/bruno_58.wav, segment:5
# data/training_data/brunomars/bruno_58.wav, segment:6
# data/training_data/brunomars/bruno_58.wav, segment:7
# data/training_data/brunomars/bruno_58.wav, segment:8
# data/training_data/brunomars/bruno_58.wav, segment:9
# data/training_data/brunomars/bruno_4.wav, segment:1
# data/training_data/brunomars/bruno_4.wav, segment:2
# data/training_data/brunomars/bruno_4.wav, segment:3
# data/training_data/brunomars/bruno_4.wav, segment:4
# data/training_data/brunomars/bruno_4.wav, segment:5
# data/training_data/brunomars/bruno_4.wav, segment:6
# data/training_data/brunomars/bruno_4.wav, segment:7
# data/training_data/brunomars/bruno_4.wav, segment:8
# data/training_data/brunomars/bruno_4.wav, segment:9
# data/training_data/brunomars/bruno_4.wav, segment:10
# data/training_data/brunomars/bruno_5.wav, segment:1
# data/training_data/brunomars/bruno_5.wav, segment:2
# data/training_data/brunomars/bruno_5.wav, segment:3
# data/training_data/brunomars/bruno_5.wav, segment:4
# data/training_data/brunomars/bruno_5.wav, segment:5
# data/training_data/brunomars/bruno_5.wav, segment:6
# data/training_data/brunomars/bruno_5.wav, segment:7
# data/training_data/brunomars/bruno_5.wav, segment:8
# data/training_data/brunomars/bruno_5.wav, segment:9
# data/training_data/brunomars/bruno_5.wav, segment:10
# data/training_data/brunomars/bruno_59.wav, segment:1
# data/training_data/brunomars/bruno_59.wav, segment:2
# data/training_data/brunomars/bruno_59.wav, segment:3
# data/training_data/brunomars/bruno_59.wav, segment:4
# data/training_data/brunomars/bruno_59.wav, segment:5
# data/training_data/brunomars/bruno_59.wav, segment:6
# data/training_data/brunomars/bruno_59.wav, segment:7
# data/training_data/brunomars/bruno_59.wav, segment:8
# data/training_data/brunomars/bruno_59.wav, segment:9
# data/training_data/brunomars/bruno_71.wav, segment:1
# data/training_data/brunomars/bruno_71.wav, segment:2
# data/training_data/brunomars/bruno_71.wav, segment:3
# data/training_data/brunomars/bruno_71.wav, segment:4
# data/training_data/brunomars/bruno_71.wav, segment:5
# data/training_data/brunomars/bruno_71.wav, segment:6
# data/training_data/brunomars/bruno_71.wav, segment:7
# data/training_data/brunomars/bruno_71.wav, segment:8
# data/training_data/brunomars/bruno_71.wav, segment:9
# data/training_data/brunomars/bruno_65.wav, segment:1
# data/training_data/brunomars/bruno_65.wav, segment:2
# data/training_data/brunomars/bruno_65.wav, segment:3
# data/training_data/brunomars/bruno_65.wav, segment:4
# data/training_data/brunomars/bruno_65.wav, segment:5
# data/training_data/brunomars/bruno_65.wav, segment:6
# data/training_data/brunomars/bruno_65.wav, segment:7
# data/training_data/brunomars/bruno_65.wav, segment:8
# data/training_data/brunomars/bruno_65.wav, segment:9
# data/training_data/brunomars/bruno_73.wav, segment:1
# data/training_data/brunomars/bruno_73.wav, segment:2
# data/training_data/brunomars/bruno_73.wav, segment:3
# data/training_data/brunomars/bruno_73.wav, segment:4
# data/training_data/brunomars/bruno_73.wav, segment:5
# data/training_data/brunomars/bruno_73.wav, segment:6
# data/training_data/brunomars/bruno_73.wav, segment:7
# data/training_data/brunomars/bruno_73.wav, segment:8
# data/training_data/brunomars/bruno_73.wav, segment:9
# data/training_data/brunomars/bruno_67.wav, segment:1
# data/training_data/brunomars/bruno_67.wav, segment:2
# data/training_data/brunomars/bruno_67.wav, segment:3
# data/training_data/brunomars/bruno_67.wav, segment:4
# data/training_data/brunomars/bruno_67.wav, segment:5
# data/training_data/brunomars/bruno_67.wav, segment:6
# data/training_data/brunomars/bruno_67.wav, segment:7
# data/training_data/brunomars/bruno_67.wav, segment:8
# data/training_data/brunomars/bruno_67.wav, segment:9
# data/training_data/brunomars/bruno_98.wav, segment:1
# data/training_data/brunomars/bruno_98.wav, segment:2
# data/training_data/brunomars/bruno_98.wav, segment:3
# data/training_data/brunomars/bruno_98.wav, segment:4
# data/training_data/brunomars/bruno_98.wav, segment:5
# data/training_data/brunomars/bruno_98.wav, segment:6
# data/training_data/brunomars/bruno_98.wav, segment:7
# data/training_data/brunomars/bruno_98.wav, segment:8
# data/training_data/brunomars/bruno_98.wav, segment:9
# data/training_data/brunomars/bruno_7.wav, segment:1
# data/training_data/brunomars/bruno_7.wav, segment:2
# data/training_data/brunomars/bruno_7.wav, segment:3
# data/training_data/brunomars/bruno_7.wav, segment:4
# data/training_data/brunomars/bruno_7.wav, segment:5
# data/training_data/brunomars/bruno_7.wav, segment:6
# data/training_data/brunomars/bruno_7.wav, segment:7
# data/training_data/brunomars/bruno_7.wav, segment:8
# data/training_data/brunomars/bruno_7.wav, segment:9
# data/training_data/brunomars/bruno_7.wav, segment:10
# data/training_data/brunomars/bruno_6.wav, segment:1
# data/training_data/brunomars/bruno_6.wav, segment:2
# data/training_data/brunomars/bruno_6.wav, segment:3
# data/training_data/brunomars/bruno_6.wav, segment:4
# data/training_data/brunomars/bruno_6.wav, segment:5
# data/training_data/brunomars/bruno_6.wav, segment:6
# data/training_data/brunomars/bruno_6.wav, segment:7
# data/training_data/brunomars/bruno_6.wav, segment:8
# data/training_data/brunomars/bruno_6.wav, segment:9
# data/training_data/brunomars/bruno_6.wav, segment:10
# data/training_data/brunomars/bruno_99.wav, segment:1
# data/training_data/brunomars/bruno_99.wav, segment:2
# data/training_data/brunomars/bruno_99.wav, segment:3
# data/training_data/brunomars/bruno_99.wav, segment:4
# data/training_data/brunomars/bruno_99.wav, segment:5
# data/training_data/brunomars/bruno_99.wav, segment:6
# data/training_data/brunomars/bruno_99.wav, segment:7
# data/training_data/brunomars/bruno_99.wav, segment:8
# data/training_data/brunomars/bruno_99.wav, segment:9
# ...
# data/training_data/maroon5/Maroon5_00015.wav, segment:6
# data/training_data/maroon5/Maroon5_00015.wav, segment:7
# data/training_data/maroon5/Maroon5_00015.wav, segment:8
# data/training_data/maroon5/Maroon5_00015.wav, segment:9
# data/training_data/maroon5/Maroon5_00015.wav, segment:10
# data/training_data/maroon5/Maroon5_00029.wav, segment:1
# data/training_data/maroon5/Maroon5_00029.wav, segment:2
# data/training_data/maroon5/Maroon5_00029.wav, segment:3
# data/training_data/maroon5/Maroon5_00029.wav, segment:4
# data/training_data/maroon5/Maroon5_00029.wav, segment:5
# data/training_data/maroon5/Maroon5_00029.wav, segment:6
# data/training_data/maroon5/Maroon5_00029.wav, segment:7
# data/training_data/maroon5/Maroon5_00029.wav, segment:8
# data/training_data/maroon5/Maroon5_00029.wav, segment:9
# data/training_data/maroon5/Maroon5_00029.wav, segment:10
# data/training_data/maroon5/Maroon5_00028.wav, segment:1
# data/training_data/maroon5/Maroon5_00028.wav, segment:2
# data/training_data/maroon5/Maroon5_00028.wav, segment:3
# data/training_data/maroon5/Maroon5_00028.wav, segment:4
# data/training_data/maroon5/Maroon5_00028.wav, segment:5
# data/training_data/maroon5/Maroon5_00028.wav, segment:6
# data/training_data/maroon5/Maroon5_00028.wav, segment:7
# data/training_data/maroon5/Maroon5_00028.wav, segment:8
# data/training_data/maroon5/Maroon5_00028.wav, segment:9
# data/training_data/maroon5/Maroon5_00028.wav, segment:10
# data/training_data/maroon5/Maroon5_00014.wav, segment:1
# data/training_data/maroon5/Maroon5_00014.wav, segment:2
# data/training_data/maroon5/Maroon5_00014.wav, segment:3
# data/training_data/maroon5/Maroon5_00014.wav, segment:4
# data/training_data/maroon5/Maroon5_00014.wav, segment:5
# data/training_data/maroon5/Maroon5_00014.wav, segment:6
# data/training_data/maroon5/Maroon5_00014.wav, segment:7
# data/training_data/maroon5/Maroon5_00014.wav, segment:8
# data/training_data/maroon5/Maroon5_00014.wav, segment:9
# data/training_data/maroon5/Maroon5_00014.wav, segment:10
# data/training_data/maroon5/Maroon5_00000.wav, segment:1
# data/training_data/maroon5/Maroon5_00000.wav, segment:2
# data/training_data/maroon5/Maroon5_00000.wav, segment:3
# data/training_data/maroon5/Maroon5_00000.wav, segment:4
# data/training_data/maroon5/Maroon5_00000.wav, segment:5
# data/training_data/maroon5/Maroon5_00000.wav, segment:6
# data/training_data/maroon5/Maroon5_00000.wav, segment:7
# data/training_data/maroon5/Maroon5_00000.wav, segment:8
# data/training_data/maroon5/Maroon5_00000.wav, segment:9
# data/training_data/maroon5/Maroon5_00000.wav, segment:10
# data/training_data/maroon5/Maroon5_00067.wav, segment:1
# data/training_data/maroon5/Maroon5_00067.wav, segment:2
# data/training_data/maroon5/Maroon5_00067.wav, segment:3
# data/training_data/maroon5/Maroon5_00067.wav, segment:4
# data/training_data/maroon5/Maroon5_00067.wav, segment:5
# data/training_data/maroon5/Maroon5_00067.wav, segment:6
# data/training_data/maroon5/Maroon5_00067.wav, segment:7
# data/training_data/maroon5/Maroon5_00067.wav, segment:8
# data/training_data/maroon5/Maroon5_00067.wav, segment:9
# data/training_data/maroon5/Maroon5_00067.wav, segment:10
# data/training_data/maroon5/Maroon5_00073.wav, segment:1
# data/training_data/maroon5/Maroon5_00073.wav, segment:2
# data/training_data/maroon5/Maroon5_00073.wav, segment:3
# data/training_data/maroon5/Maroon5_00073.wav, segment:4
# data/training_data/maroon5/Maroon5_00073.wav, segment:5
# data/training_data/maroon5/Maroon5_00073.wav, segment:6
# data/training_data/maroon5/Maroon5_00073.wav, segment:7
# data/training_data/maroon5/Maroon5_00073.wav, segment:8
# data/training_data/maroon5/Maroon5_00073.wav, segment:9
# data/training_data/maroon5/Maroon5_00073.wav, segment:10
# data/training_data/maroon5/Maroon5_00098.wav, segment:1
# data/training_data/maroon5/Maroon5_00098.wav, segment:2
# data/training_data/maroon5/Maroon5_00098.wav, segment:3
# data/training_data/maroon5/Maroon5_00098.wav, segment:4
# data/training_data/maroon5/Maroon5_00098.wav, segment:5
# data/training_data/maroon5/Maroon5_00098.wav, segment:6
# data/training_data/maroon5/Maroon5_00098.wav, segment:7
# data/training_data/maroon5/Maroon5_00098.wav, segment:8
# data/training_data/maroon5/Maroon5_00098.wav, segment:9
# data/training_data/maroon5/Maroon5_00098.wav, segment:10
# data/training_data/maroon5/Maroon5_00099.wav, segment:1
# data/training_data/maroon5/Maroon5_00099.wav, segment:2
# data/training_data/maroon5/Maroon5_00099.wav, segment:3
# data/training_data/maroon5/Maroon5_00099.wav, segment:4
# data/training_data/maroon5/Maroon5_00099.wav, segment:5
# data/training_data/maroon5/Maroon5_00099.wav, segment:6
# data/training_data/maroon5/Maroon5_00099.wav, segment:7
# data/training_data/maroon5/Maroon5_00099.wav, segment:8
# data/training_data/maroon5/Maroon5_00099.wav, segment:9
# data/training_data/maroon5/Maroon5_00099.wav, segment:10
# data/training_data/maroon5/Maroon5_00072.wav, segment:1
# data/training_data/maroon5/Maroon5_00072.wav, segment:2
# data/training_data/maroon5/Maroon5_00072.wav, segment:3
# data/training_data/maroon5/Maroon5_00072.wav, segment:4
# data/training_data/maroon5/Maroon5_00072.wav, segment:5
# data/training_data/maroon5/Maroon5_00072.wav, segment:6
# data/training_data/maroon5/Maroon5_00072.wav, segment:7
# data/training_data/maroon5/Maroon5_00072.wav, segment:8
# data/training_data/maroon5/Maroon5_00072.wav, segment:9
# data/training_data/maroon5/Maroon5_00072.wav, segment:10
# data/training_data/maroon5/Maroon5_00066.wav, segment:1
# data/training_data/maroon5/Maroon5_00066.wav, segment:2
# data/training_data/maroon5/Maroon5_00066.wav, segment:3
# data/training_data/maroon5/Maroon5_00066.wav, segment:4
# data/training_data/maroon5/Maroon5_00066.wav, segment:5
# data/training_data/maroon5/Maroon5_00066.wav, segment:6
# data/training_data/maroon5/Maroon5_00066.wav, segment:7
# data/training_data/maroon5/Maroon5_00066.wav, segment:8
# data/training_data/maroon5/Maroon5_00066.wav, segment:9
# data/training_data/maroon5/Maroon5_00066.wav, segment:10
# data/training_data/maroon5/Maroon5_00058.wav, segment:1
# data/training_data/maroon5/Maroon5_00058.wav, segment:2
# data/training_data/maroon5/Maroon5_00058.wav, segment:3
# data/training_data/maroon5/Maroon5_00058.wav, segment:4
# data/training_data/maroon5/Maroon5_00058.wav, segment:5
# data/training_data/maroon5/Maroon5_00058.wav, segment:6
# data/training_data/maroon5/Maroon5_00058.wav, segment:7
# data/training_data/maroon5/Maroon5_00058.wav, segment:8
# data/training_data/maroon5/Maroon5_00058.wav, segment:9
# data/training_data/maroon5/Maroon5_00058.wav, segment:10
# data/training_data/maroon5/Maroon5_00070.wav, segment:1
# data/training_data/maroon5/Maroon5_00070.wav, segment:2
# data/training_data/maroon5/Maroon5_00070.wav, segment:3
# data/training_data/maroon5/Maroon5_00070.wav, segment:4
# data/training_data/maroon5/Maroon5_00070.wav, segment:5
# data/training_data/maroon5/Maroon5_00070.wav, segment:6
# data/training_data/maroon5/Maroon5_00070.wav, segment:7
# data/training_data/maroon5/Maroon5_00070.wav, segment:8
# data/training_data/maroon5/Maroon5_00070.wav, segment:9
# data/training_data/maroon5/Maroon5_00070.wav, segment:10
# data/training_data/maroon5/Maroon5_00064.wav, segment:1
# data/training_data/maroon5/Maroon5_00064.wav, segment:2
# data/training_data/maroon5/Maroon5_00064.wav, segment:3
# data/training_data/maroon5/Maroon5_00064.wav, segment:4
# data/training_data/maroon5/Maroon5_00064.wav, segment:5
# data/training_data/maroon5/Maroon5_00064.wav, segment:6
# data/training_data/maroon5/Maroon5_00064.wav, segment:7
# data/training_data/maroon5/Maroon5_00064.wav, segment:8
# data/training_data/maroon5/Maroon5_00064.wav, segment:9
# data/training_data/maroon5/Maroon5_00064.wav, segment:10
# data/training_data/maroon5/Maroon5_00065.wav, segment:1
# data/training_data/maroon5/Maroon5_00065.wav, segment:2
# data/training_data/maroon5/Maroon5_00065.wav, segment:3
# data/training_data/maroon5/Maroon5_00065.wav, segment:4
# data/training_data/maroon5/Maroon5_00065.wav, segment:5
# data/training_data/maroon5/Maroon5_00065.wav, segment:6
# data/training_data/maroon5/Maroon5_00065.wav, segment:7
# data/training_data/maroon5/Maroon5_00065.wav, segment:8
# data/training_data/maroon5/Maroon5_00065.wav, segment:9
# data/training_data/maroon5/Maroon5_00065.wav, segment:10
# data/training_data/maroon5/Maroon5_00071.wav, segment:1
# data/training_data/maroon5/Maroon5_00071.wav, segment:2
# data/training_data/maroon5/Maroon5_00071.wav, segment:3
# data/training_data/maroon5/Maroon5_00071.wav, segment:4
# data/training_data/maroon5/Maroon5_00071.wav, segment:5
# data/training_data/maroon5/Maroon5_00071.wav, segment:6
# data/training_data/maroon5/Maroon5_00071.wav, segment:7
# data/training_data/maroon5/Maroon5_00071.wav, segment:8
# data/training_data/maroon5/Maroon5_00071.wav, segment:9
# data/training_data/maroon5/Maroon5_00071.wav, segment:10
# data/training_data/maroon5/Maroon5_00059.wav, segment:1
# data/training_data/maroon5/Maroon5_00059.wav, segment:2
# data/training_data/maroon5/Maroon5_00059.wav, segment:3
# data/training_data/maroon5/Maroon5_00059.wav, segment:4
# data/training_data/maroon5/Maroon5_00059.wav, segment:5
# data/training_data/maroon5/Maroon5_00059.wav, segment:6
# data/training_data/maroon5/Maroon5_00059.wav, segment:7
# data/training_data/maroon5/Maroon5_00059.wav, segment:8
# data/training_data/maroon5/Maroon5_00059.wav, segment:9
# data/training_data/maroon5/Maroon5_00059.wav, segment:10
# data/training_data/maroon5/Maroon5_00075.wav, segment:1
# data/training_data/maroon5/Maroon5_00075.wav, segment:2
# data/training_data/maroon5/Maroon5_00075.wav, segment:3
# data/training_data/maroon5/Maroon5_00075.wav, segment:4
# data/training_data/maroon5/Maroon5_00075.wav, segment:5
# data/training_data/maroon5/Maroon5_00075.wav, segment:6
# data/training_data/maroon5/Maroon5_00075.wav, segment:7
# data/training_data/maroon5/Maroon5_00075.wav, segment:8
# data/training_data/maroon5/Maroon5_00075.wav, segment:9
# data/training_data/maroon5/Maroon5_00075.wav, segment:10
# data/training_data/maroon5/Maroon5_00061.wav, segment:1
# data/training_data/maroon5/Maroon5_00061.wav, segment:2
# data/training_data/maroon5/Maroon5_00061.wav, segment:3
# data/training_data/maroon5/Maroon5_00061.wav, segment:4
# data/training_data/maroon5/Maroon5_00061.wav, segment:5
# data/training_data/maroon5/Maroon5_00061.wav, segment:6
# data/training_data/maroon5/Maroon5_00061.wav, segment:7
# data/training_data/maroon5/Maroon5_00061.wav, segment:8
# data/training_data/maroon5/Maroon5_00061.wav, segment:9
# data/training_data/maroon5/Maroon5_00061.wav, segment:10
# data/training_data/maroon5/Maroon5_00049.wav, segment:1
# data/training_data/maroon5/Maroon5_00049.wav, segment:2
# data/training_data/maroon5/Maroon5_00049.wav, segment:3
# data/training_data/maroon5/Maroon5_00049.wav, segment:4
# data/training_data/maroon5/Maroon5_00049.wav, segment:5
# data/training_data/maroon5/Maroon5_00049.wav, segment:6
# data/training_data/maroon5/Maroon5_00049.wav, segment:7
# data/training_data/maroon5/Maroon5_00049.wav, segment:8
# data/training_data/maroon5/Maroon5_00049.wav, segment:9
# data/training_data/maroon5/Maroon5_00049.wav, segment:10
# data/training_data/maroon5/Maroon5_00048.wav, segment:1
# data/training_data/maroon5/Maroon5_00048.wav, segment:2
# data/training_data/maroon5/Maroon5_00048.wav, segment:3
# data/training_data/maroon5/Maroon5_00048.wav, segment:4
# data/training_data/maroon5/Maroon5_00048.wav, segment:5
# data/training_data/maroon5/Maroon5_00048.wav, segment:6
# data/training_data/maroon5/Maroon5_00048.wav, segment:7
# data/training_data/maroon5/Maroon5_00048.wav, segment:8
# data/training_data/maroon5/Maroon5_00048.wav, segment:9
# data/training_data/maroon5/Maroon5_00048.wav, segment:10
# data/training_data/maroon5/Maroon5_00060.wav, segment:1
# data/training_data/maroon5/Maroon5_00060.wav, segment:2
# data/training_data/maroon5/Maroon5_00060.wav, segment:3
# data/training_data/maroon5/Maroon5_00060.wav, segment:4
# data/training_data/maroon5/Maroon5_00060.wav, segment:5
# data/training_data/maroon5/Maroon5_00060.wav, segment:6
# data/training_data/maroon5/Maroon5_00060.wav, segment:7
# data/training_data/maroon5/Maroon5_00060.wav, segment:8
# data/training_data/maroon5/Maroon5_00060.wav, segment:9
# data/training_data/maroon5/Maroon5_00060.wav, segment:10
# data/training_data/maroon5/Maroon5_00074.wav, segment:1
# data/training_data/maroon5/Maroon5_00074.wav, segment:2
# data/training_data/maroon5/Maroon5_00074.wav, segment:3
# data/training_data/maroon5/Maroon5_00074.wav, segment:4
# data/training_data/maroon5/Maroon5_00074.wav, segment:5
# data/training_data/maroon5/Maroon5_00074.wav, segment:6
# data/training_data/maroon5/Maroon5_00074.wav, segment:7
# data/training_data/maroon5/Maroon5_00074.wav, segment:8
# data/training_data/maroon5/Maroon5_00074.wav, segment:9
# data/training_data/maroon5/Maroon5_00074.wav, segment:10
# data/training_data/maroon5/Maroon5_00062.wav, segment:1
# data/training_data/maroon5/Maroon5_00062.wav, segment:2
# data/training_data/maroon5/Maroon5_00062.wav, segment:3
# data/training_data/maroon5/Maroon5_00062.wav, segment:4
# data/training_data/maroon5/Maroon5_00062.wav, segment:5
# data/training_data/maroon5/Maroon5_00062.wav, segment:6
# data/training_data/maroon5/Maroon5_00062.wav, segment:7
# data/training_data/maroon5/Maroon5_00062.wav, segment:8
# data/training_data/maroon5/Maroon5_00062.wav, segment:9
# data/training_data/maroon5/Maroon5_00062.wav, segment:10
# data/training_data/maroon5/Maroon5_00076.wav, segment:1
# data/training_data/maroon5/Maroon5_00076.wav, segment:2
# data/training_data/maroon5/Maroon5_00076.wav, segment:3
# data/training_data/maroon5/Maroon5_00076.wav, segment:4
# data/training_data/maroon5/Maroon5_00076.wav, segment:5
# data/training_data/maroon5/Maroon5_00076.wav, segment:6
# data/training_data/maroon5/Maroon5_00076.wav, segment:7
# data/training_data/maroon5/Maroon5_00076.wav, segment:8
# data/training_data/maroon5/Maroon5_00076.wav, segment:9
# data/training_data/maroon5/Maroon5_00076.wav, segment:10
# data/training_data/maroon5/Maroon5_00089.wav, segment:1
# data/training_data/maroon5/Maroon5_00089.wav, segment:2
# data/training_data/maroon5/Maroon5_00089.wav, segment:3
# data/training_data/maroon5/Maroon5_00089.wav, segment:4
# data/training_data/maroon5/Maroon5_00089.wav, segment:5
# data/training_data/maroon5/Maroon5_00089.wav, segment:6
# data/training_data/maroon5/Maroon5_00089.wav, segment:7
# data/training_data/maroon5/Maroon5_00089.wav, segment:8
# data/training_data/maroon5/Maroon5_00089.wav, segment:9
# data/training_data/maroon5/Maroon5_00089.wav, segment:10
# data/training_data/maroon5/Maroon5_00088.wav, segment:1
# data/training_data/maroon5/Maroon5_00088.wav, segment:2
# data/training_data/maroon5/Maroon5_00088.wav, segment:3
# data/training_data/maroon5/Maroon5_00088.wav, segment:4
# data/training_data/maroon5/Maroon5_00088.wav, segment:5
# data/training_data/maroon5/Maroon5_00088.wav, segment:6
# data/training_data/maroon5/Maroon5_00088.wav, segment:7
# data/training_data/maroon5/Maroon5_00088.wav, segment:8
# data/training_data/maroon5/Maroon5_00088.wav, segment:9
# data/training_data/maroon5/Maroon5_00088.wav, segment:10
# data/training_data/maroon5/Maroon5_00077.wav, segment:1
# data/training_data/maroon5/Maroon5_00077.wav, segment:2
# data/training_data/maroon5/Maroon5_00077.wav, segment:3
# data/training_data/maroon5/Maroon5_00077.wav, segment:4
# data/training_data/maroon5/Maroon5_00077.wav, segment:5
# data/training_data/maroon5/Maroon5_00077.wav, segment:6
# data/training_data/maroon5/Maroon5_00077.wav, segment:7
# data/training_data/maroon5/Maroon5_00077.wav, segment:8
# data/training_data/maroon5/Maroon5_00077.wav, segment:9
# data/training_data/maroon5/Maroon5_00077.wav, segment:10
# data/training_data/maroon5/Maroon5_00063.wav, segment:1
# data/training_data/maroon5/Maroon5_00063.wav, segment:2
# data/training_data/maroon5/Maroon5_00063.wav, segment:3
# data/training_data/maroon5/Maroon5_00063.wav, segment:4
# data/training_data/maroon5/Maroon5_00063.wav, segment:5
# data/training_data/maroon5/Maroon5_00063.wav, segment:6
# data/training_data/maroon5/Maroon5_00063.wav, segment:7
# data/training_data/maroon5/Maroon5_00063.wav, segment:8
# data/training_data/maroon5/Maroon5_00063.wav, segment:9
# data/training_data/maroon5/Maroon5_00063.wav, segment:10
