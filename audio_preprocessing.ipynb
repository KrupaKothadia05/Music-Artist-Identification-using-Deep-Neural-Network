# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: resampy>=0.2.2 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (21.3)
# Requirement already satisfied: decorator>=4.0.10 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (5.1.0)
# Requirement already satisfied: joblib>=0.14 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (1.0.1)
# Requirement already satisfied: numba>=0.45.1 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: soundfile>=0.10.2 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scipy>=1.2.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: audioread>=2.1.5 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: pooch>=1.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: setuptools in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: six>=1.3 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt

FIG_SIZE = (15,10)

file = "Coldplay_-_A_Sky_Full_of_Stars.mp3"

# load audio file with Librosa
signal, sample_rate = librosa.load(file, sr=22050)

# WAVEFORM
# display waveform
plt.figure(figsize=FIG_SIZE)
librosa.display.waveshow(signal, sample_rate, alpha=0.4)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /var/folders/5c/_m6k74_557zg9wwfqkptf4540000gn/T/ipykernel_58901/4060705647.py:15: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(signal, sample_rate, alpha=0.4)
# Text(0.5, 1.0, 'Waveform')

# %%
fft = np.fft.fft(signal)

# %%
magnitude = np.abs(fft)

# %%
magnitude
# Out:
# array([1729.90509861,  953.70300492, 1232.57835358, ...,  320.76631781,
#        1232.57835358,  953.70300492])

# %%
# FFT -> power spectrum
# perform Fourier transform
fft = np.fft.fft(signal)

# calculate abs values on complex numbers to get magnitude
spectrum = np.abs(fft)

# create frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# take half of the spectrum and frequency
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# plot spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(left_f, left_spectrum, alpha=0.4)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power spectrum")
# Out:
# Text(0.5, 1.0, 'Power spectrum')

# %%
n_fft = 2048
hop_length = 512
spectrogram = librosa.core.stft(signal,hop_length=hop_length,n_fft=n_fft)

# %%
librosa.display.specshow(spectrogram, sr=sample_rate,hop_length=hop_length)
# Out:
# /Users/vaishakkallampad/opt/anaconda3/envs/tensorflow/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   return f(*args, **kwargs)

# %%
# STFT -> spectrogram
hop_length = 512 # in num. of samples
n_fft = 2048 # window in num. of samples

# calculate duration hop length and window in seconds
hop_length_duration = float(hop_length)/sample_rate
n_fft_duration = float(n_fft)/sample_rate

print("STFT hop length duration is: {}s".format(hop_length_duration))
print("STFT window duration is: {}s".format(n_fft_duration))

# perform stft
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# calculate abs values on complex numbers to get magnitude
spectrogram = np.abs(stft)

# display spectrogram
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram")

# apply logarithm to cast amplitude to Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# STFT hop length duration is: 0.023219954648526078s
# STFT window duration is: 0.09287981859410431s
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
MFCCs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# display MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")

# show plots
plt.show()

# %%
np.shape(MFCCs)
# Out:
# (13, 10182)
