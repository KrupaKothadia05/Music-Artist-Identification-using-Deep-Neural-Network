# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# path to json file that stores MFCCs and genre labels for each processed segment
DATA_PATH = "data_2.json"

def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y


if __name__ == "__main__":

    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu'),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu'),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu'),

        # output layer
        keras.layers.Dense(2, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)
# Out:
# Data succesfully loaded!
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 1690)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 512)               865792
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 1,013,698
# Trainable params: 1,013,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 44/44 [==============================] - 1s 8ms/step - loss: 11.6403 - accuracy: 0.6573 - val_loss: 1.7066 - val_accuracy: 0.8139
# Epoch 2/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8629 - accuracy: 0.8663 - val_loss: 0.9700 - val_accuracy: 0.8477
# Epoch 3/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3318 - accuracy: 0.9216 - val_loss: 1.1759 - val_accuracy: 0.8562
# Epoch 4/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1444 - accuracy: 0.9689 - val_loss: 0.9303 - val_accuracy: 0.8663
# Epoch 5/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9873 - val_loss: 1.0396 - val_accuracy: 0.8748
# Epoch 6/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 0.9946 - val_loss: 1.0099 - val_accuracy: 0.8748
# Epoch 7/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 0.9891 - val_loss: 1.1196 - val_accuracy: 0.8697
# Epoch 8/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.9837 - val_loss: 1.1315 - val_accuracy: 0.8799
# Epoch 9/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9684 - val_loss: 0.9551 - val_accuracy: 0.8731
# Epoch 10/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0316 - accuracy: 0.9936 - val_loss: 0.7633 - val_accuracy: 0.8849
# Epoch 11/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.8648 - val_accuracy: 0.8866
# Epoch 12/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9883 - val_loss: 0.7468 - val_accuracy: 0.8900
# Epoch 13/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0325 - accuracy: 0.9899 - val_loss: 0.8174 - val_accuracy: 0.8866
# Epoch 14/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0511 - accuracy: 0.9839 - val_loss: 0.7579 - val_accuracy: 0.8951
# Epoch 15/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0291 - accuracy: 0.9901 - val_loss: 0.7403 - val_accuracy: 0.8900
# Epoch 16/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.6609 - val_accuracy: 0.9036
# Epoch 17/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.1661e-04 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.9103
# Epoch 18/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3413e-04 - accuracy: 1.0000 - val_loss: 0.6620 - val_accuracy: 0.9086
# Epoch 19/50
# 44/44 [==============================] - 0s 6ms/step - loss: 9.5290e-05 - accuracy: 1.0000 - val_loss: 0.6621 - val_accuracy: 0.9086
# Epoch 20/50
# 44/44 [==============================] - 0s 6ms/step - loss: 8.9209e-05 - accuracy: 1.0000 - val_loss: 0.6625 - val_accuracy: 0.9103
# Epoch 21/50
# 44/44 [==============================] - 0s 6ms/step - loss: 7.1899e-05 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.9069
# Epoch 22/50
# 44/44 [==============================] - 0s 6ms/step - loss: 7.3464e-05 - accuracy: 1.0000 - val_loss: 0.6630 - val_accuracy: 0.9086
# Epoch 23/50
# 44/44 [==============================] - 0s 6ms/step - loss: 6.7410e-05 - accuracy: 1.0000 - val_loss: 0.6631 - val_accuracy: 0.9069
# Epoch 24/50
# 44/44 [==============================] - 0s 6ms/step - loss: 7.2686e-05 - accuracy: 1.0000 - val_loss: 0.6635 - val_accuracy: 0.9069
# Epoch 25/50
# 44/44 [==============================] - 0s 6ms/step - loss: 5.8646e-05 - accuracy: 1.0000 - val_loss: 0.6638 - val_accuracy: 0.9069
# Epoch 26/50
# 44/44 [==============================] - 0s 6ms/step - loss: 4.3176e-05 - accuracy: 1.0000 - val_loss: 0.6638 - val_accuracy: 0.9069
# Epoch 27/50
# 44/44 [==============================] - 0s 7ms/step - loss: 5.0375e-05 - accuracy: 1.0000 - val_loss: 0.6642 - val_accuracy: 0.9086
# Epoch 28/50
# 44/44 [==============================] - 0s 6ms/step - loss: 4.8518e-05 - accuracy: 1.0000 - val_loss: 0.6644 - val_accuracy: 0.9086
# Epoch 29/50
# 44/44 [==============================] - 0s 6ms/step - loss: 4.2458e-05 - accuracy: 1.0000 - val_loss: 0.6648 - val_accuracy: 0.9086
# Epoch 30/50
# 44/44 [==============================] - 0s 6ms/step - loss: 4.9778e-05 - accuracy: 1.0000 - val_loss: 0.6647 - val_accuracy: 0.9086
# Epoch 31/50
# 44/44 [==============================] - 0s 6ms/step - loss: 3.4145e-05 - accuracy: 1.0000 - val_loss: 0.6649 - val_accuracy: 0.9086
# Epoch 32/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.2608e-05 - accuracy: 1.0000 - val_loss: 0.6650 - val_accuracy: 0.9086
# Epoch 33/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.8509e-05 - accuracy: 1.0000 - val_loss: 0.6651 - val_accuracy: 0.9086
# Epoch 34/50
# 44/44 [==============================] - 0s 6ms/step - loss: 3.9776e-05 - accuracy: 1.0000 - val_loss: 0.6653 - val_accuracy: 0.9086
# Epoch 35/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.7982e-05 - accuracy: 1.0000 - val_loss: 0.6654 - val_accuracy: 0.9086
# Epoch 36/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4388e-05 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.9086
# Epoch 37/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.4443e-05 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.9086
# Epoch 38/50
# 44/44 [==============================] - 0s 6ms/step - loss: 3.1324e-05 - accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.9086
# Epoch 39/50
# 44/44 [==============================] - 0s 7ms/step - loss: 3.0134e-05 - accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.9086
# Epoch 40/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.4454e-05 - accuracy: 1.0000 - val_loss: 0.6661 - val_accuracy: 0.9086
# Epoch 41/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.9084e-05 - accuracy: 1.0000 - val_loss: 0.6658 - val_accuracy: 0.9086
# Epoch 42/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.5920e-05 - accuracy: 1.0000 - val_loss: 0.6658 - val_accuracy: 0.9086
# Epoch 43/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.7463e-05 - accuracy: 1.0000 - val_loss: 0.6658 - val_accuracy: 0.9036
# Epoch 44/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.1099e-05 - accuracy: 1.0000 - val_loss: 0.6655 - val_accuracy: 0.9069
# Epoch 45/50
# 44/44 [==============================] - 0s 7ms/step - loss: 2.4746e-05 - accuracy: 1.0000 - val_loss: 0.6653 - val_accuracy: 0.9069
# Epoch 46/50
# 44/44 [==============================] - 0s 7ms/step - loss: 2.3921e-05 - accuracy: 1.0000 - val_loss: 0.6651 - val_accuracy: 0.9069
# Epoch 47/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.4736e-05 - accuracy: 1.0000 - val_loss: 0.6653 - val_accuracy: 0.9069
# Epoch 48/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.6937e-05 - accuracy: 1.0000 - val_loss: 0.6652 - val_accuracy: 0.9069
# Epoch 49/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.5194e-05 - accuracy: 1.0000 - val_loss: 0.6654 - val_accuracy: 0.9086
# Epoch 50/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.7132e-05 - accuracy: 1.0000 - val_loss: 0.6656 - val_accuracy: 0.9086
