# Epoch 41/50
# 275/275 [==============================] - 7s 27ms/step - loss: 0.1758 - accuracy: 0.9356 - val_loss: 0.3049 - val_accuracy: 0.8971
# Epoch 42/50
# 275/275 [==============================] - 7s 26ms/step - loss: 0.1707 - accuracy: 0.9417 - val_loss: 0.3141 - val_accuracy: 0.8912
# Epoch 43/50
# 275/275 [==============================] - 8s 29ms/step - loss: 0.1756 - accuracy: 0.9407 - val_loss: 0.3087 - val_accuracy: 0.8944
# Epoch 44/50
# 275/275 [==============================] - 8s 30ms/step - loss: 0.1647 - accuracy: 0.9397 - val_loss: 0.3385 - val_accuracy: 0.8871
# Epoch 45/50
# 275/275 [==============================] - 8s 29ms/step - loss: 0.1653 - accuracy: 0.9418 - val_loss: 0.3053 - val_accuracy: 0.9007
# Epoch 46/50
# 275/275 [==============================] - 8s 28ms/step - loss: 0.1531 - accuracy: 0.9476 - val_loss: 0.2890 - val_accuracy: 0.8998
# Epoch 47/50
# 275/275 [==============================] - 9s 32ms/step - loss: 0.1539 - accuracy: 0.9469 - val_loss: 0.2966 - val_accuracy: 0.8985
# Epoch 48/50
# 275/275 [==============================] - 11s 38ms/step - loss: 0.1537 - accuracy: 0.9453 - val_loss: 0.3282 - val_accuracy: 0.8980
# Epoch 49/50
# 275/275 [==============================] - 9s 32ms/step - loss: 0.1558 - accuracy: 0.9422 - val_loss: 0.3078 - val_accuracy: 0.9021
# Epoch 50/50
# 275/275 [==============================] - 8s 30ms/step - loss: 0.1449 - accuracy: 0.9431 - val_loss: 0.2888 - val_accuracy: 0.9053
# 115/115 - 1s - loss: 0.2767 - accuracy: 0.9090
#
# Test accuracy: 0.9090163707733154
# Target: 1, Predicted label: [1]

# %%
import soundfile as sf

# %%
import json
import os
import math
import librosa

SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=10):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    #import soundfile
    #sfo = soundfile.SoundFile(librosa.ex('audio'))
    
    signal, sample_rate = librosa.load(path, sr=SAMPLE_RATE)
    #signal, sample_rate = wavfile.read(path)

    #sample_rate, signal = path

    # process all segments of audio file
    for d in range(num_segments):

        # calculate start and finish sample for current segment
        start = samples_per_segment * d
        finish = start + samples_per_segment

        # extract mfcc
        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
        mfcc = mfcc.T

        # store only mfcc feature with expected number of vectors
        if len(mfcc) == num_mfcc_vectors_per_segment:
            data["mfcc"].append(mfcc.tolist())
           
    return data

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (2.9.4)
# Requirement already satisfied: pandas in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (1.2.4)
# Requirement already satisfied: analytics-python in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (1.4.0)
# Requirement already satisfied: orjson in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (3.6.8)
# Requirement already satisfied: numpy in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (1.20.1)
# Requirement already satisfied: pillow in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (8.2.0)
# Requirement already satisfied: pycryptodome in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (3.14.1)
# Requirement already satisfied: aiohttp in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (3.8.1)
# Requirement already satisfied: pydub in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: paramiko in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (2.10.4)
# Requirement already satisfied: requests in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (2.25.1)
# Requirement already satisfied: fastapi in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (0.75.2)
# Requirement already satisfied: python-multipart in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (0.0.5)
# Requirement already satisfied: Jinja2 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (2.11.3)
# Requirement already satisfied: matplotlib in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (3.5.1)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (2.1.0)
# Requirement already satisfied: uvicorn in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (0.17.6)
# Requirement already satisfied: ffmpy in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (2.0.12)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (20.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: idna>=2.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->gradio) (2.10)
# Requirement already satisfied: six>=1.5 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from analytics-python->gradio) (1.15.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from analytics-python->gradio) (1.6)
# Requirement already satisfied: backoff==1.10.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from analytics-python->gradio) (1.10.0)
# Requirement already satisfied: python-dateutil>2.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from analytics-python->gradio) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from requests->gradio) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from requests->gradio) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from requests->gradio) (4.0.0)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from fastapi->gradio) (1.9.0)
# Requirement already satisfied: starlette==0.17.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from fastapi->gradio) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.0.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from starlette==0.17.1->fastapi->gradio) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi->gradio) (3.7.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from Jinja2->gradio) (1.1.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.1.1)
# Requirement already satisfied: linkify-it-py~=1.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]->gradio) (1.0.3)
# Requirement already satisfied: mdit-py-plugins in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py[linkify,plugins]->gradio) (0.3.0)
# Requirement already satisfied: uc-micro-py in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio) (1.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->gradio) (4.29.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->gradio) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->gradio) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->gradio) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->gradio) (20.9)
# Requirement already satisfied: pytz>=2017.3 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from pandas->gradio) (2021.1)
# Requirement already satisfied: cryptography>=2.5 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from paramiko->gradio) (3.4.7)
# Requirement already satisfied: pynacl>=1.0.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from paramiko->gradio) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from paramiko->gradio) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko->gradio) (1.14.5)
# Requirement already satisfied: pycparser in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->gradio) (2.20)
# Requirement already satisfied: click>=7.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from uvicorn->gradio) (7.1.2)
# Requirement already satisfied: asgiref>=3.4.0 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from uvicorn->gradio) (3.5.0)
# Requirement already satisfied: h11>=0.8 in /Users/vaishakkallampad/opt/anaconda3/lib/python3.8/site-packages (from uvicorn->gradio) (0.13.0)

# %%
import gradio as gr

# %%
def predict_audio(path):
    MFCC = save_mfcc(path, num_segments=10)
    X = np.array(MFCC["mfcc"])
    X = X[...,np.newaxis]
    prediction = model.predict(X)

    map = {0:"brunomars",
           1: "greenday",
           2:  "Migos",
           3:  "Beyonce",
           4:  "maroon5"}
    predicted_index = np.argmax(prediction, axis=1)
#     print(prediction)
#     print(predicted_index)
    import statistics as st
    ans = map[st.mode(predicted_index)]
    return ans

# %%
from IPython.lib.display import Audio
a = gr.inputs.Audio(source="upload", type="filepath", label=None, optional=False)
label = gr.outputs.Label(num_top_classes=5)

gr.Interface(fn=predict_audio, inputs=a, outputs=label,interpretation='default').launch(debug='True')
# Out:
# Running on local URL:  http://127.0.0.1:7860/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7860/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Keyboard interruption in main thread... closing server.
# (<fastapi.applications.FastAPI at 0x7f8d81a8ceb0>,
#  'http://127.0.0.1:7860/',
#  None)
